# %% [markdown]
# <center>
#     <center><h3>New York Housing Market - EDA</h3><br>
# <center> This notebook serves as a showcase of my Exploratory Data Analysis (EDA) ability in Python. The purpose of EDA is to gain a comprehensive understanding of a dataset's structure, patterns, and relationships through visual and statistical exploration. By examining data distributions, identifying outliers, and assessing data quality, EDA informs subsequent analysis and hypothesis generation, facilitating effective communication of insights to stakeholders. Therefore, this notebook will primarily emphasize visualisations to ensure that the narrative within the data can be effectively communicated to stakeholders, regardless of their statistical proficiency.
#
# <center><br>The aim of this project is to explore the relationship between demographics of new york residents, their incomes and the location of their housing from the New York census and a New York City housing market database.
#
#    **NY Housing Market Dataset:** [Click Here](https://www.kaggle.com/datasets/nelgiriyewithana/new-york-housing-market/data)
#     <br>**Brooklyn Housing Market Dataset 2015:** [Click Here](https://www.kaggle.com/datasets/tianhwu/brooklynhomes2003to2017/data)
#    <br>**NY Census Datasets:** [Click Here](https://www.kaggle.com/datasets/muonneutrino/new-york-city-census-data/data)

# %% [markdown]
# <left>
#     <left><h3> Importing Libraries and Data </h3><br>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px
import geopandas as gp
# %matplotlib inline

# %% [markdown]
# <left>
#     <left><h3> Check For Missing Data</h3><br>

# %%
housing = pd.read_csv('NY-House-Dataset.csv', index_col=0)
census = pd.read_csv('nyc_census_tracts.csv', index_col=0)
census_loc = pd.read_csv('census_block_loc.csv', index_col=0)

# %%
housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4801 entries, Brokered by Douglas Elliman  -111 Fifth Ave to Brokered by Nyc Realty Brokers Llc
# Data columns (total 16 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   TYPE                         4801 non-null   object
#  1   PRICE                        4801 non-null   int64
#  2   BEDS                         4801 non-null   int64
#  3   BATH                         4801 non-null   float64
#  4   PROPERTYSQFT                 4801 non-null   float64
#  5   ADDRESS                      4801 non-null   object
#  6   STATE                        4801 non-null   object
#  7   MAIN_ADDRESS                 4801 non-null   object
#  8   ADMINISTRATIVE_AREA_LEVEL_2  4801 non-null   object
#  9   LOCALITY                     4801 non-null   object
#  10  SUBLOCALITY                  4801 non-null   object
#  11  STREET_NAME                  4801 non-null   object
#  12  LONG_NAME                    4801 non-null   object
#  13  FORMATTED_ADDRESS            4801 non-null   object
#  14  LATITUDE                     4801 non-null   float64
#  15  LONGITUDE                    4801 non-null   float64
# dtypes: float64(4), int64(2), object(10)
# memory usage: 637.6+ KB

# %% [markdown]
# <br><h4><left> No missing data.

# %%
census.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2167 entries, 36005000100 to 36085990100
# Data columns (total 35 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   County           2167 non-null   object
#  1   Borough          2167 non-null   object
#  2   TotalPop         2167 non-null   int64
#  3   Men              2167 non-null   int64
#  4   Women            2167 non-null   int64
#  5   Hispanic         2128 non-null   float64
#  6   White            2128 non-null   float64
#  7   Black            2128 non-null   float64
#  8   Native           2128 non-null   float64
#  9   Asian            2128 non-null   float64
#  10  Citizen          2167 non-null   int64
#  11  Income           2101 non-null   float64
#  12  IncomeErr        2101 non-null   float64
#  13  IncomePerCap     2121 non-null   float64
#  14  IncomePerCapErr  2121 non-null   float64
#  15  Poverty          2125 non-null   float64
#  16  ChildPoverty     2107 non-null   float64
#  17  Professional     2124 non-null   float64
#  18  Service          2124 non-null   float64
#  19  Office           2124 non-null   float64
#  20  Construction     2124 non-null   float64
#  21  Production       2124 non-null   float64
#  22  Drive            2124 non-null   float64
#  23  Carpool          2124 non-null   float64
#  24  Transit          2124 non-null   float64
#  25  Walk             2124 non-null   float64
#  26  OtherTransp      2124 non-null   float64
#  27  WorkAtHome       2124 non-null   float64
#  28  MeanCommute      2106 non-null   float64
#  29  Employed         2167 non-null   int64
#  30  PrivateWork      2124 non-null   float64
#  31  PublicWork       2124 non-null   float64
#  32  SelfEmployed     2124 non-null   float64
#  33  FamilyWork       2124 non-null   float64
#  34  Unemployment     2125 non-null   float64
# dtypes: float64(28), int64(5), object(2)
# memory usage: 609.5+ KB

# %% [markdown]
# <br><h4><left> Most columns contain missing data. No more than ~ 3% however.

# %%
census_loc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Float64Index: 38396 entries, 40.48 to 40.93
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Longitude  38396 non-null  float64
#  1   BlockCode  38396 non-null  int64
#  2   County     38396 non-null  object
#  3   State      38396 non-null  object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 1.5+ MB

# %% [markdown]
# <br><h4><left> Significant amount of missing data, however, the loss seems very structured given most columns contain either 18053 data points or 12777.
#     <br> - It seems likely that there is a class in the dataframe, perhaps a whole county, containing null values.

# %% [markdown]
# <left>
#     <left><h3> Data Overview</h3><br>

# %%
housing.head()
# Out:
#                                                                   TYPE  \
# BROKERTITLE
# Brokered by Douglas Elliman  -111 Fifth Ave             Condo for sale
# Brokered by Serhant                                     Condo for sale
# Brokered by Sowae Corp                                  House for sale
# Brokered by COMPASS                                     Condo for sale
# Brokered by Sotheby's International Realty - Ea...  Townhouse for sale
#
#                                                         PRICE  BEDS  \
# BROKERTITLE
# Brokered by Douglas Elliman  -111 Fifth Ave            315000     2
# Brokered by Serhant                                 195000000     7
# Brokered by Sowae Corp                                 260000     4
# Brokered by COMPASS                                     69000     3
# Brokered by Sotheby's International Realty - Ea...   55000000     7
#
#                                                          BATH  PROPERTYSQFT  \
# BROKERTITLE
# Brokered by Douglas Elliman  -111 Fifth Ave          2.000000        1400.0
# Brokered by Serhant                                 10.000000       17545.0
# Brokered by Sowae Corp                               2.000000        2015.0
# Brokered by COMPASS                                  1.000000         445.0
# Brokered by Sotheby's International Realty - Ea...   2.373861       14175.0
#
#                                                                                               ADDRESS  \
# BROKERTITLE
# Brokered by Douglas Elliman  -111 Fifth Ave                                      2 E 55th St Unit 803
# Brokered by Serhant                                 Central Park Tower Penthouse-217 W 57th New Yo...
# Brokered by Sowae Corp                                                               620 Sinclair Ave
# Brokered by COMPASS                                                           2 E 55th St Unit 908W33
# Brokered by Sotheby's International Realty - Ea...                                        5 E 64th St
#
#                                                                       STATE  \
# BROKERTITLE
# Brokered by Douglas Elliman  -111 Fifth Ave              New York, NY 10022
# Brokered by Serhant                                      New York, NY 10019
# Brokered by Sowae Corp                              Staten Island, NY 10312
# Brokered by COMPASS                                     Manhattan, NY 10022
# Brokered by Sotheby's International Realty - Ea...       New York, NY 10065
#
#                                                                                          MAIN_ADDRESS  \
# BROKERTITLE
# Brokered by Douglas Elliman  -111 Fifth Ave                    2 E 55th St Unit 803New York, NY 10022
# Brokered by Serhant                                 Central Park Tower Penthouse-217 W 57th New Yo...
# Brokered by Sowae Corp                                        620 Sinclair AveStaten Island, NY 10312
# Brokered by COMPASS                                        2 E 55th St Unit 908W33Manhattan, NY 10022
# Brokered by Sotheby's International Realty - Ea...                      5 E 64th StNew York, NY 10065
#
#                                                    ADMINISTRATIVE_AREA_LEVEL_2  \
# BROKERTITLE
# Brokered by Douglas Elliman  -111 Fifth Ave                    New York County
# Brokered by Serhant                                              United States
# Brokered by Sowae Corp                                           United States
# Brokered by COMPASS                                              United States
# Brokered by Sotheby's International Realty - Ea...               United States
#
#                                                     LOCALITY      SUBLOCALITY  \
# BROKERTITLE
# Brokered by Douglas Elliman  -111 Fifth Ave         New York        Manhattan
# Brokered by Serhant                                 New York  New York County
# Brokered by Sowae Corp                              New York  Richmond County
# Brokered by COMPASS                                 New York  New York County
# Brokered by Sotheby's International Realty - Ea...  New York  New York County
#
#                                                          STREET_NAME  \
# BROKERTITLE
# Brokered by Douglas Elliman  -111 Fifth Ave         East 55th Street
# Brokered by Serhant                                         New York
# Brokered by Sowae Corp                                 Staten Island
# Brokered by COMPASS                                         New York
# Brokered by Sotheby's International Realty - Ea...          New York
#
#                                                            LONG_NAME  \
# BROKERTITLE
# Brokered by Douglas Elliman  -111 Fifth Ave          Regis Residence
# Brokered by Serhant                                 West 57th Street
# Brokered by Sowae Corp                               Sinclair Avenue
# Brokered by COMPASS                                 East 55th Street
# Brokered by Sotheby's International Realty - Ea...  East 64th Street
#
#                                                                                     FORMATTED_ADDRESS  \
# BROKERTITLE
# Brokered by Douglas Elliman  -111 Fifth Ave         Regis Residence, 2 E 55th St #803, New York, N...
# Brokered by Serhant                                            217 W 57th St, New York, NY 10019, USA
# Brokered by Sowae Corp                                 620 Sinclair Ave, Staten Island, NY 10312, USA
# Brokered by COMPASS                                              2 E 55th St, New York, NY 10022, USA
# Brokered by Sotheby's International Realty - Ea...               5 E 64th St, New York, NY 10065, USA
#
#                                                      LATITUDE  LONGITUDE
# BROKERTITLE
# Brokered by Douglas Elliman  -111 Fifth Ave         40.761255 -73.974483
# Brokered by Serhant                                 40.766393 -73.980991
# Brokered by Sowae Corp                              40.541805 -74.196109
# Brokered by COMPASS                                 40.761398 -73.974613
# Brokered by Sotheby's International Realty - Ea...  40.767224 -73.969856

# %%
census.head()
# Out:
#             County Borough  TotalPop   Men  Women  Hispanic  White  Black  \
# CensusTract
# 36005000100  Bronx   Bronx      7703  7133    570      29.9    6.1   60.9
# 36005000200  Bronx   Bronx      5403  2659   2744      75.8    2.3   16.0
# 36005000400  Bronx   Bronx      5915  2896   3019      62.7    3.6   30.7
# 36005001600  Bronx   Bronx      5879  2558   3321      65.1    1.6   32.4
# 36005001900  Bronx   Bronx      2591  1206   1385      55.4    9.0   29.0
#
#              Native  Asian  ...  Walk  OtherTransp  WorkAtHome  MeanCommute  \
# CensusTract                 ...
# 36005000100     0.2    1.6  ...   NaN          NaN         NaN          NaN
# 36005000200     0.0    4.2  ...   2.9          0.0         0.0         43.0
# 36005000400     0.0    0.3  ...   1.4          0.5         2.1         45.0
# 36005001600     0.0    0.0  ...   8.6          1.6         1.7         38.8
# 36005001900     0.0    2.1  ...   3.0          2.4         6.2         45.4
#
#              Employed  PrivateWork  PublicWork  SelfEmployed  FamilyWork  \
# CensusTract
# 36005000100         0          NaN         NaN           NaN         NaN
# 36005000200      2308         80.8        16.2           2.9         0.0
# 36005000400      2675         71.7        25.3           2.5         0.6
# 36005001600      2120         75.0        21.3           3.8         0.0
# 36005001900      1083         76.8        15.5           7.7         0.0
#
#              Unemployment
# CensusTract
# 36005000100           NaN
# 36005000200           7.7
# 36005000400           9.5
# 36005001600           8.7
# 36005001900          19.2
#
# [5 rows x 35 columns]

# %%
census_loc.head()
# Out:
#           Longitude        BlockCode     County State
# Latitude
# 40.48    -74.280000  340230076002012  Middlesex    NJ
# 40.48    -74.276834  340230076005000  Middlesex    NJ
# 40.48    -74.273668  340230076003018  Middlesex    NJ
# 40.48    -74.270503  340230076003004  Middlesex    NJ
# 40.48    -74.267337  340230074021000  Middlesex    NJ

# %%
print
("housing dataset dimensions: {}".format(housing.shape),
"census dataset dimensions: {}".format(census.shape),
"census location dataset dimensions: {}".format(census_loc.shape))
# Out:
# ('housing dataset dimensions: (4801, 16)',
#  'census dataset dimensions: (2167, 35)',
#  'census location dataset dimensions: (38396, 4)')

# %% [markdown]
# <br><left> - The dataset, <i>census_loc</i> contains the coordinates and block codes for different blocks within the city of New York.
#     <br> - The <i>census</i> dataset contains the census tract codes (codes for designated geospatial areas) from the whole of the NY State.
#     <br>- First we must combine these two, relating the block codes from <i>census_loc</i> to the tract codes in <i>census</i>.
#     <br>- Later, we can merge the resultant dataset with the <i>housing</i> dataset, through their shared coordinate data.

# %% [markdown]
# <left>
#     <left><h3> Combining Census Datasets</h3><br>
#         <br> Let's filter out the counties from the "County" column in the <i>census_loc</i> dataset that aren't in the city.
#         <br> Next, we'll create a new column in the <i>census_loc</i> dataset called "Tract", and fill it with census tract values, found by removing the 4 digits at the end of block code values.
#         <br> Then, we can perform a left merge on the <i>census_loc</i> dataset through the new "Tract" column and the <i>census</i> dataset's "CensusTract" column.

# %%
census_loc = census_loc[census_loc["County"].isin(['Bronx','Kings','New York','Queens','Richmond'])]
census_loc["Tract"] = census_loc.BlockCode // 10000
census_loc = census_loc.merge(census,how='left',right_index=True,left_on='Tract')
census_loc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Float64Index: 18053 entries, 40.48 to 40.9164321608
# Data columns (total 40 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Longitude        18053 non-null  float64
#  1   BlockCode        18053 non-null  int64
#  2   County_x         18053 non-null  object
#  3   State            18053 non-null  object
#  4   Tract            18053 non-null  int64
#  5   County_y         18052 non-null  object
#  6   Borough          18052 non-null  object
#  7   TotalPop         18052 non-null  float64
#  8   Men              18052 non-null  float64
#  9   Women            18052 non-null  float64
#  10  Hispanic         12999 non-null  float64
#  11  White            12999 non-null  float64
#  12  Black            12999 non-null  float64
#  13  Native           12999 non-null  float64
#  14  Asian            12999 non-null  float64
#  15  Citizen          18052 non-null  float64
#  16  Income           11947 non-null  float64
#  17  IncomeErr        11947 non-null  float64
#  18  IncomePerCap     12838 non-null  float64
#  19  IncomePerCapErr  12838 non-null  float64
#  20  Poverty          12830 non-null  float64
#  21  ChildPoverty     12401 non-null  float64
#  22  Professional     12777 non-null  float64
#  23  Service          12777 non-null  float64
#  24  Office           12777 non-null  float64
#  25  Construction     12777 non-null  float64
#  26  Production       12777 non-null  float64
#  27  Drive            12777 non-null  float64
#  28  Carpool          12777 non-null  float64
#  29  Transit          12777 non-null  float64
#  30  Walk             12777 non-null  float64
#  31  OtherTransp      12777 non-null  float64
#  32  WorkAtHome       12777 non-null  float64
#  33  MeanCommute      11864 non-null  float64
#  34  Employed         18052 non-null  float64
#  35  PrivateWork      12777 non-null  float64
#  36  PublicWork       12777 non-null  float64
#  37  SelfEmployed     12777 non-null  float64
#  38  FamilyWork       12777 non-null  float64
#  39  Unemployment     12830 non-null  float64
# dtypes: float64(34), int64(2), object(4)
# memory usage: 5.6+ MB

# %%
census_loc.head(10)
# Out:
#            Longitude        BlockCode  County_x State        Tract  County_y  \
# Latitude
# 40.480000 -74.232513  360859901000011  Richmond    NY  36085990100  Richmond
# 40.480000 -74.229347  360859901000011  Richmond    NY  36085990100  Richmond
# 40.480000 -74.226181  360859901000011  Richmond    NY  36085990100  Richmond
# 40.480000 -74.223015  360859901000011  Richmond    NY  36085990100  Richmond
# 40.480000 -74.219849  360859901000011  Richmond    NY  36085990100  Richmond
# 40.480000 -74.216683  360859901000010  Richmond    NY  36085990100  Richmond
# 40.480000 -74.213518  360859901000010  Richmond    NY  36085990100  Richmond
# 40.482261 -74.238844  360859901000012  Richmond    NY  36085990100  Richmond
# 40.482261 -74.235678  360859901000011  Richmond    NY  36085990100  Richmond
# 40.482261 -74.232513  360859901000011  Richmond    NY  36085990100  Richmond
#
#                  Borough  TotalPop  Men  Women  ...  Walk  OtherTransp  \
# Latitude                                        ...
# 40.480000  Staten Island       0.0  0.0    0.0  ...   NaN          NaN
# 40.480000  Staten Island       0.0  0.0    0.0  ...   NaN          NaN
# 40.480000  Staten Island       0.0  0.0    0.0  ...   NaN          NaN
# 40.480000  Staten Island       0.0  0.0    0.0  ...   NaN          NaN
# 40.480000  Staten Island       0.0  0.0    0.0  ...   NaN          NaN
# 40.480000  Staten Island       0.0  0.0    0.0  ...   NaN          NaN
# 40.480000  Staten Island       0.0  0.0    0.0  ...   NaN          NaN
# 40.482261  Staten Island       0.0  0.0    0.0  ...   NaN          NaN
# 40.482261  Staten Island       0.0  0.0    0.0  ...   NaN          NaN
# 40.482261  Staten Island       0.0  0.0    0.0  ...   NaN          NaN
#
#            WorkAtHome  MeanCommute  Employed  PrivateWork  PublicWork  \
# Latitude
# 40.480000         NaN          NaN       0.0          NaN         NaN
# 40.480000         NaN          NaN       0.0          NaN         NaN
# 40.480000         NaN          NaN       0.0          NaN         NaN
# 40.480000         NaN          NaN       0.0          NaN         NaN
# 40.480000         NaN          NaN       0.0          NaN         NaN
# 40.480000         NaN          NaN       0.0          NaN         NaN
# 40.480000         NaN          NaN       0.0          NaN         NaN
# 40.482261         NaN          NaN       0.0          NaN         NaN
# 40.482261         NaN          NaN       0.0          NaN         NaN
# 40.482261         NaN          NaN       0.0          NaN         NaN
#
#            SelfEmployed  FamilyWork  Unemployment
# Latitude
# 40.480000           NaN         NaN           NaN
# 40.480000           NaN         NaN           NaN
# 40.480000           NaN         NaN           NaN
# 40.480000           NaN         NaN           NaN
# 40.480000           NaN         NaN           NaN
# 40.480000           NaN         NaN           NaN
# 40.480000           NaN         NaN           NaN
# 40.482261           NaN         NaN           NaN
# 40.482261           NaN         NaN           NaN
# 40.482261           NaN         NaN           NaN
#
# [10 rows x 40 columns]

# %%
census_loc.Income = pd.to_numeric(census_loc.Income,errors='coerce')

# %% [markdown]
# <left>
#     <left><h3> Investigating Missing Values</h3><br>
#         <br> As visible from the cell above, after combining our datasets, the top rows of our new dataset are missing data. We discovered this in our New York state data earlier, but now it's clear a group of datapoints from inside the city are missing. <br>Lets plot the first missing datapoint from the table header above: (40.48, -74.232513).

# %%
import folium


# Coordinates to plot
coordinates = (-74.232513, 40.48)

# Create a map centered around the given coordinates
nyc_map = folium.Map(location=[coordinates[1], coordinates[0]], zoom_start=12)

# Add a marker for the coordinate
folium.Marker([coordinates[1], coordinates[0]], popup="Coordinate").add_to(nyc_map)

# Save the map as an HTML file
nyc_map.save("nyc_map.html")

# %%
from IPython.display import IFrame

# Path to the map HTML file
html_file_path = 'nyc_map.html'

# Display the map in the notebook
IFrame(src=html_file_path, width=700, height=500)
# Out:
#         <iframe
#             width="700"
#             height="500"
#             src="nyc_map.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# <br> From the map above, the missing datapoints are clearly erroneous, appearing to be located by the New York, New Jersey border, above the sea. For this reason we can exclude these data points from the rest of our analysis, as they also seem to be the source of the missing values visible in the table above and in the check for missing data nearer the beginning of the notebook.

# %%
census_loc["Income"].describe()
# Out:
# count     11947.000000
# mean      66464.034737
# std       26952.609291
# min        9829.000000
# 25%       45991.000000
# 50%       66250.000000
# 75%       84559.000000
# max      244375.000000
# Name: Income, dtype: float64

# %%
def convert_to_2d(lats,lons,values):
    latmin = 40.48
    lonmin = -74.28
    latmax = 40.93
    lonmax = -73.65
    lon_vals = np.mgrid[lonmin:lonmax:200j]
    lat_vals = np.mgrid[latmin:latmax:200j]
    map_values = np.zeros([200,200])
    dlat = lat_vals[1] - lat_vals[0]
    dlon = lon_vals[1] - lon_vals[0]
    for lat,lon,value in zip(lats,lons,values):
        lat_idx = int(np.rint((lat - latmin) / dlat))
        lon_idx = int(np.rint((lon-lonmin) / dlon ))        
        if not np.isnan(value):
            map_values[lon_idx,lat_idx] = value
    return lat_vals,lon_vals,map_values

# %%
def make_plot(data_values,title='',colors='Greens'):
    lat_vals,lon_vals,values = convert_to_2d(census_loc.index,census_loc.Longitude,data_values)
    fig = plt.figure(1,figsize=[10,10])
    limits = np.min(lon_vals),np.max(lon_vals),np.min(lat_vals),np.max(lat_vals)
    
    im = plt.imshow(values.T,origin='lower',cmap=colors,extent=limits)
    plt.xlabel('Longitude [degrees]')
    plt.ylabel('Latitude [degrees]')
    plt.title(title)
    plt.colorbar(im,fraction=0.035, pad=0.04)
    
    plt.show()

# %%
make_plot(census_loc.Income,colors='Blues',title='NYC Income Distribution')
